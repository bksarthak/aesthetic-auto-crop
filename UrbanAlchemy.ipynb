# %% [markdown]
# # The Alchemist's Eye 👁️
# This notebook acts as an algorithmic Art Director. It automatically allocates a free NVIDIA Cloud GPU to execute Meta's heavy SAM-2 models without exhausting your personal laptop's memory.
#
# **The Demo Dataset**
# Just hit **Run All**! By default, this notebook is configured to analyze two high-fidelity street photography compositions included in our `demo_dataset` directory, bypassing the need to authenticate Google Drive instantly.

# %%
# 1. Clone the repository and install deep learning frameworks
# !git clone https://github.com/bksarthak/aesthetic-auto-crop.git
# %cd aesthetic-auto-crop
# !pip install -r requirements.txt

# 2. (Optional) Mount your Google Drive to analyze your own catalog
from google.colab import drive
# drive.mount("/content/drive")

# %%
import os

# 3. Configure API Keys and Targets
# Discover masterpieces inside our included Demo Dataset, or swap this path to your Drive!
TARGET_DIRECTORY = "/content/aesthetic-auto-crop/demo_dataset"
# Set this to the folder in your Google Drive holding your RAW/JPG files
TARGET_DIRECTORY = '/content/drive/MyDrive/Photography/18-april-2026'

# 4. Ignite the Pipeline!
# !python discover.py $TARGET_DIRECTORY --engine cloud
